# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# read the data in a pandas dataframe 
data = pd.read_csv("austin_weather.csv")

# %%
data.head(5)
#seeing shape of the dataset
print(data.shape)
# Out:
# (1319, 21)

# %%
data.fillna(data.mean())
# Out:
# C:\Users\Nihaar Mahajan\AppData\Local\Temp\ipykernel_8488\520690265.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean())
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
#      HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                     93                 75                 57
# 1                     93                 68                 43
# 2                     76                 52                 27
# 3                     89                 56                 22
# 4                     86                 71                 56
# ...                  ...                ...                ...
# 1314                  82                 54                 25
# 1315                  87                 54                 20
# 1316                  82                 51                 19
# 1317                  69                 48                 27
# 1318                  64                 43                 22
#
#      SeaLevelPressureAvgInches VisibilityHighMiles VisibilityAvgMiles  \
# 0                        29.68                  10                  7
# 1                        30.13                  10                 10
# 2                        30.49                  10                 10
# 3                        30.45                  10                 10
# 4                        30.33                  10                 10
# ...                        ...                 ...                ...
# 1314                     29.97                  10                 10
# 1315                      29.9                  10                 10
# 1316                     29.86                  10                 10
# 1317                     29.91                  10                 10
# 1318                     29.97                  10                 10
#
#      VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                     2          20          4          31
# 1                     5          16          6          25
# 2                    10           8          3          12
# 3                     7          12          4          20
# 4                     7          10          2          16
# ...                 ...         ...        ...         ...
# 1314                 10          12          5          21
# 1315                 10          14          5          20
# 1316                 10          12          4          17
# 1317                 10          13          4          20
# 1318                 10          12          4          20
#
#      PrecipitationSumInches
# 0                      0.46
# 1                         0
# 2                         0
# 3                         0
# 4                         T
# ...                     ...
# 1314                      0
# 1315                      0
# 1316                      0
# 1317                      0
# 1318                      0
#
# [1319 rows x 17 columns]

# %%
data = data.replace('T', 1)

# %%
data = data.replace('-', 1)

# %%
df = pd.DataFrame(data)

# %%
df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'TempHighF'}>,
#         <AxesSubplot: title={'center': 'TempAvgF'}>],
#        [<AxesSubplot: title={'center': 'TempLowF'}>, <AxesSubplot: >]],
#       dtype=object)
